# %% [markdown]
# #### Assuntos
# - Tipos de variáveis
# - Comandos de entrada e saída
# - Comando Condicional

# %% [markdown]
# ###Questão 1:
#
# Peça ao usuário um número inteiro como entrada e imprima se o número é PAR ou ÍMPAR.

# %%
numero = int(input("digite um inteiro: "))

if (numero%2 == 0):
  print("o número é par!!!")
else:
  print("o número é ímpar!!!")

# %% [markdown]
# ### Questão 2:
#
#
# Escreva um programa que peça a data atual (dia, mês e ano como números inteiros) e peça a data de nascimento do usuário (dia, mês e ano como números inteiros). O programa deve imprimir a idade do usuário.

# %%
dia, mes, ano = input("digite o dia, o mês e ano atuais: ").split()
dia = int(dia)
mes = int(mes)
ano =int(ano)
dia_aniv, mes_aniv, ano_aniv = input("digite o dia, o mês e ano do seu aniversário: ").split()
dia_aniv = int(dia_aniv)
mes_aniv = int(mes_aniv)
ano_aniv = int(ano_aniv)

idade = 0
idade_meses = 0

if ano >= ano_aniv:
  if ano > ano_aniv:
    if mes >= mes_aniv:
      if mes > mes_aniv:
        print(f"você tem {ano-ano_aniv} anos e {mes-mes_aniv} meses")
      else:
        print(f"você tem {ano-ano_aniv} anos")
    else:
      print(f"você tem {ano-ano_aniv-1} anos e {12-(mes_aniv-mes)} meses")

  if ano == ano_aniv:
    if mes >= mes_aniv:
      if mes > mes_aniv:
        print(f"você tem {mes-mes_aniv} meses de vida")

      if mes == mes_aniv:
        if dia >= dia_aniv:
          if dia > dia_aniv:
            print(f"você tem {dia-dia_aniv} dias de vida")

          else:
            print("Parabéns, você nasceu hoje!")
# Out:
# digite o dia, o mês e ano atuais: 25 10 2023
# digite o dia, o mês e ano do seu aniversário: 25 11 2020
# você tem 2 anos e 11 meses

# %% [markdown]
# ### Questão 3:
#
# Escreva um programa que verifique se um ponto está dentro de um círculo. Você deve receber dois inteiros (a,b) e um inteiro r que são a posição do centro da circunferência e o valor de seu raio respectivamente. Logo em seguida, você irá pedir o valor do ponto (x,y) que deve ser checado se está dentro ou fora da circunferência. Considere que se o ponto estiver exatamente em cima do bordo da circunferência ele é considerado dentro da circunferência.

# %%
a, b = input("digite as coordenadas da origem do círculo: ").split()
r = int(input("digite o valor do raio do círculo: "))

x, y = input("digite as coordenadas de um ponto arbitrário: ").split()
novo_x = int(x) - int(a)
novo_y = int(y) - int(b)

distancia_origem = (((novo_x)**2) + ((novo_y)**2)) ** (1/2)

if distancia_origem < r:
  print(f"o ponto ({x}, {y}) está dentro do círculo")
elif distancia_origem == r:
  print(f"o ponto ({x}, {y}) está na borda do círculo")
else:
  print(f"o ponto ({x}, {y}) está fora do círculo")

# %% [markdown]
# ### Questão 4:
#
# Tendo como dados de entrada a altura (float) e o sexo (M ou F) de uma pessoa, construa um algoritmo que calcule seu peso esperado médio, utilizando as seguintes fórmulas:
#
# ● para homens: (72.7 * h) – 58;
#
# ● para mulheres: (62.1 * h) – 44.7.

# %%
altura = float(input("digite sua altura em metros: "))
sexo = input("digite seu sexo (M para masculino e F para feminino): ")

if sexo == "M":
  peso = (72.7*altura) - 58
else:
  peso = (62.1*altura) - 44.7

print(f"seu peso estimado é {peso}kg")
# Out:
# digite sua altura em metros: 1.58
# digite seu sexo (M para masculino e F para feminino):
# seu peso estimado é 53.418000000000006kg

# %% [markdown]
# ### Questão 5:
#
# O IMC – Indice de Massa Corporal é um critério da Organização Mundial de Saúde para dar umaindicação sobre a condição de peso de uma pessoa adulta. A fórmula é IMC = $\frac{\text{peso}}{ \text{altura}^2}$. Elabore um algoritmo que leia o peso e a altura de um adulto e mostre sua condição de acordo com a tabela abaixo.
#
# **IMC em adultos: Condição**
#
# Abaixo de 18,5: Abaixo do peso
#
# Entre 18,5 e 25: Peso normal
#
# Entre 25 e 30: Acima do peso
#
# Acima de 30: obeso

# %%
altura = float(input("digite sua altura em m: "))
peso = float(input("digite seu peso em kg: "))

imc = peso / (altura**2)

if imc > 18.5:
  print(f"seu imc está {imc}, você está abaixo do peso ideal")
elif (18.5 <= imc < 25):
  print(f"seu imc está {imc}, você está no peso ideal")
elif (25 <= imc < 30):
  print(f"seu imc está {imc}, você está acima do peso ideal")
else:
  print(f"seu imc está {imc}, você está obeso")

# %% [markdown]
# ### Questão 6:
#
# Escreva um algoritmo que leia as 3 notas obtidas por um aluno nas 3 verificações e a média dos exercícios que fazem parte da avaliação, e calcule a média de aproveitamento, usando a fórmula:
# MA := (nota1 + nota 2 * 2 + nota 3 * 3 + ME)/7
#
# A atribuição dos conceitos obedece a tabela abaixo. O algoritmo deve escrever suas notas, a média dos exercícios, a média de aproveitamento, o conceito correspondente e a mensagem 'Aprovado' se o conceito for A, B ou C, e 'Reprovado' se o conceito for D ou E.
#
# ** Média de aproveitamento -> Conceito **
#
# $>=$ 90  -> A
#
# $>=$ 75 e $<$ 90 -> B
#
# $>=$ 60 e $<$ 75 -> C
#
# $>=$ 40 e $<$ 60 -> D
#
# $<$ 40 -> E

# %%
nota1, nota2, nota3 = input("digite suas 3 notas: ")

media = (float(nota1) + float(nota2) + float(nota3))/3

if media >= 90:
  print(f"sua nota é A")
elif (75 <= media < 90):
  print(f"sua nota é B")
elif (60 <= media < 75):
  print(f"sua nota é C")
elif (40 <= media < 60):
  print(f"sua nota é D")
else:
  print("sua nota é E")

# %% [markdown]
# ### Questão 7:
#
# Escreva um programa que funciona como uma calculadora para operações binárias (com dois operandos):
# O usuário deve dar os valores de ponto flutuante X e Y dos operandos e o tipo da operação (que pode ser “+”, “-”, “*”, “/”) como entrada.
#
# O programa deve imprimir na tela o cálculo da operação:
# X OPERACAO Y.

# %%
x = input("digite um operador")
a, b = input("digite dois valores para fazer a operação: ").split()

valor = 0

if x == "*":
  valor = int(a) * int(b)
elif x == "/":
  valor = int(a) / int(b)
elif x == "+":
  valor = int(a) + int(b)
else:
  valor = int(a) - int(b)

print(f"{a} {x} {b} = {valor}")
